# %%
import scgen
import scanpy as sc
import pandas as pd
import numpy as np
from metrics import compute_entropy, silhouette_coeff_ASW

sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=100)
sc.settings.set_figure_params(dpi_save=300)
sc.logging.print_version_and_date()
# Out:
# Running Scanpy 1.7.2, on 2021-06-17 14:00.

# %%
train_scgen = sc.read_h5ad('/media/bgi/zhouruilong/deepMNN/data/dataset4.h5ad')

sc.pp.normalize_total(train_scgen)
sc.pp.log1p(train_scgen)
sc.pp.highly_variable_genes(train_scgen, n_top_genes=7000)
train_scgen = train_scgen[:,train_scgen.var.highly_variable]
# Out:
# normalizing counts per cell
#     finished (0:00:00)
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
#     finished (0:00:02)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
train_scgen.obs["cell_type"] = train_scgen.obs["celltype"].tolist()
# Out:
# Trying to set attribute `.obs` of view, copying.

# %%
train_scgen = scgen.setup_anndata(train_scgen, batch_key="batch", labels_key="cell_type",  copy=True)
# Out:
# INFO     Using batches from adata.obs["batch"]
# INFO     Using labels from adata.obs["cell_type"]
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Successfully registered anndata object containing 14767 cells, 7000 vars, 5 batches,
#          15 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0
#          extra continuous covariates.
# INFO     Please do not further modify adata until model is trained.

# %%
model = scgen.SCGEN(train_scgen)
# Out:
# /media/bgi/zhouruilong/anaconda3/envs/scGen/lib/python3.7/site-packages/scvi/model/base/_base_model.py:148: UserWarning: Make sure the registered X field in anndata contains unnormalized count data.
#   "Make sure the registered X field in anndata contains unnormalized count data."

# %%
model.train(
    max_epochs=100,
    batch_size=32,
    early_stopping=True,
    early_stopping_patience=25,
    use_gpu=True
)
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Epoch 27/100:  27%|██▋       | 27/100 [03:00<08:09,  6.70s/it, loss=276, v_num=1]

# %%
adata_scgen = model.batch_removal()

adata_scgen.obsm['X_pca'] = adata_scgen.obsm['corrected_latent']
sc.pp.neighbors(adata_scgen)
sc.tl.umap(adata_scgen)
# Out:
# /media/bgi/zhouruilong/anaconda3/envs/scGen/lib/python3.7/site-packages/scvi/model/base/_base_model.py:148: UserWarning: Make sure the registered X field in anndata contains unnormalized count data.
#   "Make sure the registered X field in anndata contains unnormalized count data."
# INFO     Input adata not setup with scvi. attempting to transfer anndata setup
# INFO     Using data from adata.X
# INFO     Computing library size prior per batch
# INFO     Registered keys:['X', 'batch_indices', 'local_l_mean', 'local_l_var', 'labels']
# INFO     Successfully registered anndata object containing 14767 cells, 7000 vars, 5 batches,
#          15 labels, and 0 proteins. Also registered 0 extra categorical covariates and 0
#          extra continuous covariates.
# /media/bgi/zhouruilong/anaconda3/envs/scGen/lib/python3.7/site-packages/scvi/model/base/_base_model.py:148: UserWarning: Make sure the registered X field in anndata contains unnormalized count data.
#   "Make sure the registered X field in anndata contains unnormalized count data."
# computing neighbors
#     using 'X_pca' with n_pcs = 100
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:39)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:17)

# %%
adata_scgen.obs['batch'] = adata_scgen.obs['batchlb'].tolist()
sc.pl.umap(adata_scgen,color='batch',save='_figure5_scgen_batch.pdf')
sc.pl.umap(adata_scgen,color='celltype',save='_figure5_scgen_celltype.pdf')
# Out:
# ... storing 'batch' as categorical
# ... storing 'batchlb' as categorical
# ... storing 'celltype' as categorical
# ... storing 'cell_type' as categorical
# WARNING: saving figure to file figures/umap_figure5_scgen_batch.pdf
# WARNING: saving figure to file figures/umap_figure5_scgen_celltype.pdf

# %%
asw_scgen = silhouette_coeff_ASW(adata_scgen)
entropy_scgen = compute_entropy(adata_scgen)
# Out:
# Calculating entropy ...
# use exist neighbors
# /media/bgi/zhouruilong/deepMNN/Reproduction of result/scGen/metrics.py:53: FutureWarning: This location for 'connectivities' is deprecated. It has been moved to .obsp[connectivities], and will not be accesible here in a future version of anndata.
#   knn_graph = adata.uns['neighbors']['connectivities']
# Entropy calculated!

# %%
asw_scgen.to_csv('/media/bgi/zhouruilong/deepMNN/csv_result/fig5/asw_scgen_fig5.csv',index=0)
entropy_scgen.to_csv('/media/bgi/zhouruilong/deepMNN/csv_result/fig5/entropy_scgen_fig5.csv',index=0)

# %%
adata_scgen.write('/media/bgi/zhouruilong/deepMNN/processed_adata/adata_scgen_fig5.h5ad')
