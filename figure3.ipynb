# %%
import os
import time
import warnings
import pandas as pd
import scanpy as sc
import seaborn as sns
import matplotlib.pyplot as plt
from deepMNN import correct_scanpy
from metrics import compute_entropy, silhouette_coeff_ASW

warnings.filterwarnings("ignore")

sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=100)
sc.settings.set_figure_params(dpi_save=300)
sc.logging.print_version_and_date()

os.environ["CUDA_VISIBLE_DEVICES"]="1"
# Out:
# Running Scanpy 1.6.0, on 2021-04-14 17:37.

# %%
# adata1 = sc.read_text('../github_code/Batch-effect-removal-benchmarking/Data/dataset5/b1_exprs.txt').T
# info1 = pd.read_csv('../github_code/Batch-effect-removal-benchmarking/Data/dataset5/b1_celltype.txt', sep='\t', index_col=0)
# adata1.obs['celltype'] = info1.CellType

# adata2 = sc.read_text('../github_code/Batch-effect-removal-benchmarking/Data/dataset5/b2_exprs.txt').T
# info2 = pd.read_csv('../github_code/Batch-effect-removal-benchmarking/Data/dataset5/b2_celltype.txt', sep='\t', index_col=0)
# adata2.obs['celltype'] = info2.CellType

# adata = adata1.concatenate(adata2)

# adata.write_h5ad('data/dataset5.h5ad')
# Out:
# ... storing 'celltype' as categorical

# %%
adata = sc.read_h5ad('data/dataset5.h5ad')

sc.pp.normalize_per_cell(adata, counts_per_cell_after=1e4)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, n_top_genes=2000)
adata = adata[:,adata.var.highly_variable]
sc.pp.scale(adata, max_value=10)
sc.tl.pca(adata, svd_solver='arpack')
# Out:
# normalizing by total count per cell
#     finished (0:00:02): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
#     finished (0:00:06)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:04)

# %%
batch_names = adata.obs['batch'].value_counts().index.values
adatas = [adata[adata.obs['batch'] == batch_names[i]] for i in range(0, len(batch_names))]

# %% [markdown]
# # Before batch correction

# %%
sc.pp.neighbors(adata)
sc.tl.umap(adata)
asw_raw = silhouette_coeff_ASW(adata)
entropy_raw=compute_entropy(adata)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:20)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:22)
# Calculating entropy ...
# use exist neighbors
# Entropy calculated!

# %%
adata.obs['batch'] = ['10X 3\'' if i == '0' else '10X 5\'' for i in adata.obs['batch']]
sc.pl.umap(adata,color='batch',save='_figure3_raw_batch.pdf')
# Out:
# ... storing 'batch' as categorical
# WARNING: saving figure to file figures/umap_figure2_raw_batch.pdf

# %%
sc.pl.umap(adata,color='celltype',save='_figure3_raw_celltype.pdf')
# Out:
# WARNING: saving figure to file figures/umap_figure2_raw_celltype.pdf

# %% [markdown]
# # Batch correction using deepMNN

# %%
time_s = time.time()
corrected = correct_scanpy(adatas)
print('time used:', time.time()-time_s)

adata_result = corrected[0].concatenate(corrected[1:], join='inner', batch_key = 'batch')
sc.tl.pca(adata_result, svd_solver='arpack')
sc.pp.neighbors(adata_result)
sc.tl.umap(adata_result)

asw_deepMNN = silhouette_coeff_ASW(adata_result)
entropy_deepMNN=compute_entropy(adata_result)
# Out:
# [[0.         0.63842924]
#  [0.         0.        ]]
# Epoch 0, loss: 1110.774, counter: 0
# Learning rate = 0.1000000
# Epoch 1, loss: 933.316, counter: 0
# Learning rate = 0.1000000
# Epoch 2, loss: 812.236, counter: 0
# Learning rate = 0.1000000
# Epoch 3, loss: 544.303, counter: 0
# Learning rate = 0.1000000
# Epoch 4, loss: 253.149, counter: 0
# Learning rate = 0.1000000
# Epoch 5, loss: 142.367, counter: 0
# Learning rate = 0.1000000
# Epoch 6, loss: 103.384, counter: 0
# Learning rate = 0.1000000
# Epoch 7, loss: 87.414, counter: 0
# Learning rate = 0.1000000
# Epoch 8, loss: 77.519, counter: 0
# Learning rate = 0.1000000
# Epoch 9, loss: 69.613, counter: 0
# Learning rate = 0.1000000
# Epoch 10, loss: 65.450, counter: 0
# Learning rate = 0.1000000
# Epoch 11, loss: 63.408, counter: 0
# Learning rate = 0.1000000
# Epoch 12, loss: 64.883, counter: 1
# Learning rate = 0.1000000
# Epoch 13, loss: 63.909, counter: 2
# Learning rate = 0.1000000
# Epoch 14, loss: 58.868, counter: 0
# Learning rate = 0.1000000
# Epoch 15, loss: 57.362, counter: 0
# Learning rate = 0.1000000
# Epoch 16, loss: 59.833, counter: 1
# Learning rate = 0.1000000
# Epoch 17, loss: 56.715, counter: 0
# Learning rate = 0.1000000
# Epoch 18, loss: 54.382, counter: 0
# Learning rate = 0.1000000
# Epoch 19, loss: 55.012, counter: 1
# Learning rate = 0.0800000
# Epoch 20, loss: 46.731, counter: 0
# Learning rate = 0.0800000
# Epoch 21, loss: 47.016, counter: 1
# Learning rate = 0.0800000
# Epoch 22, loss: 45.292, counter: 0
# Learning rate = 0.0800000
# Epoch 23, loss: 43.307, counter: 0
# Learning rate = 0.0800000
# Epoch 24, loss: 43.831, counter: 1
# Learning rate = 0.0800000
# Epoch 25, loss: 43.403, counter: 2
# Learning rate = 0.0800000
# Epoch 26, loss: 44.077, counter: 3
# Learning rate = 0.0800000
# Epoch 27, loss: 42.107, counter: 0
# Learning rate = 0.0800000
# Epoch 28, loss: 42.637, counter: 1
# Learning rate = 0.0800000
# Epoch 29, loss: 41.788, counter: 0
# Learning rate = 0.0800000
# Epoch 30, loss: 43.163, counter: 1
# Learning rate = 0.0800000
# Epoch 31, loss: 42.169, counter: 2
# Learning rate = 0.0800000
# Epoch 32, loss: 42.381, counter: 3
# Learning rate = 0.0800000
# Epoch 33, loss: 40.752, counter: 0
# Learning rate = 0.0800000
# Epoch 34, loss: 40.115, counter: 0
# Learning rate = 0.0800000
# Epoch 35, loss: 38.685, counter: 0
# Learning rate = 0.0800000
# Epoch 36, loss: 38.404, counter: 0
# Learning rate = 0.0800000
# Epoch 37, loss: 38.825, counter: 1
# Learning rate = 0.0800000
# Epoch 38, loss: 37.636, counter: 0
# Learning rate = 0.0800000
# Epoch 39, loss: 37.930, counter: 1
# Learning rate = 0.0640000
# Epoch 40, loss: 36.188, counter: 0
# Learning rate = 0.0640000
# Epoch 41, loss: 33.094, counter: 0
# Learning rate = 0.0640000
# Epoch 42, loss: 32.007, counter: 0
# Learning rate = 0.0640000
# Epoch 43, loss: 31.619, counter: 0
# Learning rate = 0.0640000
# Epoch 44, loss: 32.130, counter: 1
# Learning rate = 0.0640000
# Epoch 45, loss: 32.780, counter: 2
# Learning rate = 0.0640000
# Epoch 46, loss: 36.622, counter: 3
# Learning rate = 0.0640000
# Epoch 47, loss: 55.246, counter: 4
# Learning rate = 0.0640000
# Epoch 48, loss: 38.611, counter: 5
# Learning rate = 0.0640000
# Epoch 49, loss: 34.557, counter: 6
# Learning rate = 0.0640000
# Epoch 50, loss: 31.755, counter: 7
# Learning rate = 0.0640000
# Epoch 51, loss: 30.186, counter: 0
# Learning rate = 0.0640000
# Epoch 52, loss: 30.320, counter: 1
# Learning rate = 0.0640000
# Epoch 53, loss: 29.940, counter: 0
# Learning rate = 0.0640000
# Epoch 54, loss: 30.018, counter: 1
# Learning rate = 0.0640000
# Epoch 55, loss: 30.113, counter: 2
# Learning rate = 0.0640000
# Epoch 56, loss: 29.708, counter: 0
# Learning rate = 0.0640000
# Epoch 57, loss: 30.404, counter: 1
# Learning rate = 0.0640000
# Epoch 58, loss: 31.097, counter: 2
# Learning rate = 0.0640000
# Epoch 59, loss: 30.892, counter: 3
# Learning rate = 0.0512000
# Epoch 60, loss: 27.937, counter: 0
# Learning rate = 0.0512000
# Epoch 61, loss: 27.444, counter: 0
# Learning rate = 0.0512000
# Epoch 62, loss: 28.402, counter: 1
# Learning rate = 0.0512000
# Epoch 63, loss: 25.709, counter: 0
# Learning rate = 0.0512000
# Epoch 64, loss: 24.656, counter: 0
# Learning rate = 0.0512000
# Epoch 65, loss: 23.789, counter: 0
# Learning rate = 0.0512000
# Epoch 66, loss: 24.295, counter: 1
# Learning rate = 0.0512000
# Epoch 67, loss: 143.639, counter: 2
# Learning rate = 0.0512000
# Epoch 68, loss: 72.008, counter: 3
# Learning rate = 0.0512000
# Epoch 69, loss: 43.364, counter: 4
# Learning rate = 0.0512000
# Epoch 70, loss: 38.178, counter: 5
# Learning rate = 0.0512000
# Epoch 71, loss: 34.010, counter: 6
# Learning rate = 0.0512000
# Epoch 72, loss: 30.991, counter: 7
# Learning rate = 0.0512000
# Epoch 73, loss: 27.455, counter: 8
# Learning rate = 0.0512000
# Epoch 74, loss: 28.288, counter: 9
# Learning rate = 0.0512000
# Epoch 75, loss: 26.898, counter: 10
# Learning rate = 0.0512000
# Finished training
# time used: 210.94193315505981
# computing PCA
#     with n_comps=50
#     finished (0:00:03)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:07)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:30)
# Calculating entropy ...
# use exist neighbors
# Entropy calculated!

# %%
adata_result.obs['batch'] = ['10X 3\'' if i == '0' else '10X 5\'' for i in adata_result.obs['batch']]
sc.pl.umap(adata_result,color='batch',save='_figure3_deepMNN_batch.pdf')
# Out:
# ... storing 'batch' as categorical
# WARNING: saving figure to file figures/umap_figure2_deepMNN_batch.pdf

# %%
sc.pl.umap(adata_result,color='celltype',save='_figure3_deepMNN_celltype.pdf')
# Out:
# WARNING: saving figure to file figures/umap_figure2_deepMNN_celltype.pdf

# %% [markdown]
# # Batch correction using Scanorama

# %%
import scanorama

adata = sc.read_h5ad('data/dataset5.h5ad')

sc.pp.normalize_per_cell(adata)
sc.pp.log1p(adata)
sc.pp.highly_variable_genes(adata, n_top_genes=2000, flavor='seurat')
adata = adata[:,adata.var['highly_variable']]

adatas = [adata[adata.obs['batch'] == i,:].copy() for i in ['0','1']]

time_s = time.time()
corrected = scanorama.correct_scanpy(adatas)
print('time used:', time.time()-time_s)

corrected_dataset = corrected[0].concatenate(corrected[1:], join='inner', batch_key = 'batch')
sc.tl.pca(corrected_dataset, svd_solver='arpack')
sc.pp.neighbors(corrected_dataset)
sc.tl.umap(corrected_dataset)

asw_Scanorama = silhouette_coeff_ASW(corrected_dataset)
entropy_Scanorama=compute_entropy(corrected_dataset)
# Out:
# normalizing by total count per cell
#     finished (0:00:35): normalized adata.X and added    'n_counts', counts per cell before normalization (adata.obs)
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
#     finished (0:05:02)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)
# Found 1998 genes among all datasets
# [[0.         0.55470487]
#  [0.         0.        ]]
# Processing datasets (0, 1)
# time used: 36.99869513511658
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:10)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:13)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:18)
# Calculating entropy ...
# use exist neighbors
# Entropy calculated!

# %%
corrected_dataset.obs['batch'] = ['10X 3\'' if i == '0' else '10X 5\'' for i in corrected_dataset.obs['batch']]
sc.pl.umap(corrected_dataset,color='batch',save='_figure3_Scanorama_batch.pdf')
# Out:
# ... storing 'batch' as categorical
# WARNING: saving figure to file figures/umap_figure2_Scanorama_batch.pdf

# %%
sc.pl.umap(corrected_dataset,color='celltype',save='_figure3_Scanorama_celltype.pdf')
# Out:
# WARNING: saving figure to file figures/umap_figure2_Scanorama_celltype.pdf

# %% [markdown]
# # Metrics

# %%
asw_df = pd.DataFrame()
asw_df['ASW F1 score'] = asw_raw['fscore'].tolist() + asw_Scanorama['fscore'].tolist() + asw_deepMNN['fscore'].tolist()
asw_df['Methods'] = (['Raw'] * asw_raw.shape[0] + 
                     ['Scanorama'] * asw_raw.shape[0] + 
                     ['deepMNN'] * asw_raw.shape[0])

# plt.figure(dpi=300)

sns.set_theme(style='white', palette='pastel')
sns.boxplot(x='Methods', y='ASW F1 score', width=0.4, data=asw_df)
plt.title('Distribution of ASW F1 score')
plt.xlabel('')
plt.savefig('figures/ASW_F1_score_figure3.pdf', format='pdf', dpi=300, bbox_inches='tight')

# %%
entropy_df = pd.DataFrame()
entropy_df['Entropy'] = (entropy_raw['cell_type'].tolist() + entropy_raw['batch'].tolist() + 
                         entropy_Scanorama['cell_type'].tolist() + entropy_Scanorama['batch'].tolist() + 
                         entropy_deepMNN['cell_type'].tolist() + entropy_deepMNN['batch'].tolist())
entropy_df['Methods'] = (['Raw'] * entropy_raw.shape[0] * 2 + 
                         ['Scanorama'] * entropy_raw.shape[0] * 2 + 
                         ['deepMNN'] * entropy_raw.shape[0] * 2)
entropy_df['Entropy_type'] = (['cell_type'] * entropy_raw.shape[0] + ['batch'] * entropy_raw.shape[0] + 
                              ['cell_type'] * entropy_raw.shape[0] + ['batch'] * entropy_raw.shape[0] + 
                              ['cell_type'] * entropy_raw.shape[0] + ['batch'] * entropy_raw.shape[0])

# plt.figure(dpi=300)

sns.set_theme(style='white', palette="pastel")

sns.boxplot(x='Methods', y='Entropy',
            hue='Entropy_type', palette=['y', 'g'], data=entropy_df)
plt.title('Batch and cell type entropies')
plt.xlabel('')
plt.legend(bbox_to_anchor=(1.05, 0.6), borderaxespad=0)
plt.savefig('figures/Entropy_figure3.pdf', format='pdf', dpi=300, bbox_inches='tight')
